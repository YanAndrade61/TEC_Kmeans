# %%
import pandas as pd
from kmeans import Kmeans

# %% [markdown]
# Load data in a numpy array of points multi-dimensional

# %%
path = "dados.csv"
data = pd.read_csv(path)
data = data.iloc[:,:4].to_numpy()

# %% [markdown]
# Load model Kmeans with the data and number of clusters

# %%
model = Kmeans(data,4)

# %% [markdown]
# Simulation with different combination of parameters

# %%
model.simulate(first_centroids="random_point", it=1000, error_stop=0.0001)
model.view_clusters("Simulation1.png")

# %%
model.simulate(first_centroids="random_vector", it=1000, error_stop=0.0001)
model.view_clusters("Simulation1.png")
